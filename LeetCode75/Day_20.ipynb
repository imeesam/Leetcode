# %% [markdown]
# ![image.png](attachment:acaee5a0-8dca-4bd4-8f76-a9baa0a961e2.png)

# %% [markdown]
# ![image.png](attachment:9bcb3e43-40f6-4bf9-b3e2-ecdf0e1a05d5.png)

# %% [markdown]
# ![image.png](attachment:067180df-4f67-4306-8300-1aa7d478279e.png)

# %% [markdown]
# ![image.png](attachment:b3bc76b1-8ada-45d4-a3b6-6d6643599e99.png)

# %% [markdown]
# ![image.png](attachment:9153d2db-413b-4147-b155-6c1e3a6bf2c3.png)

# %% [markdown]
# ![image.png](attachment:a97e8d56-ec3d-4446-b08b-20d3792f7b52.png)

# %% [markdown]
# ![image.png](attachment:1510760b-2efb-4ae3-9fd8-2f349d7ea9c9.png)

# %% [markdown]
# ![image.png](attachment:5958dde3-2188-48e5-a03b-f99465727585.png)

# %% [markdown]
# ![image.png](attachment:172235f1-3ef1-4050-8aad-00fb5d111180.png)

# %% [markdown]
# ![image.png](attachment:e2eefb25-f9e7-47ce-afe4-7067b1a1f381.png)

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
    def print_list(self):
        current = self
        while current:
            print(current.val, end=" -> ")
            current = current.next
        print("None")

# %%
l4 = ListNode(4)
l3 = ListNode(3, l4)
l2 = ListNode(2, l3)
l1 = ListNode(1, l2)

# %%
l1.print_list()
# Out:
# 1 -> 2 -> 3 -> 4 -> None

# %%
def swapp(head):
    dummy = ListNode(0)
    dummy.next =  head
    cur = dummy
    while cur.next and cur.next.next:
        first = cur.next
        second = cur.next.next

        cur.next = second
        first.next = second.next
        second.next = first
        
        cur = first
        
    return dummy.next

# %%
a = swapp(l1)
a.print_list()
# Out:
# 2 -> 1 -> 4 -> 3 -> None

# %%
l1.print_list()
# Out:
# 1 -> 2 -> 3 -> 4 -> None
