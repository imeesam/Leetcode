# %% [markdown]
# ![image.png](attachment:40fce2c6-284e-4e8c-8d9e-ba44883aa910.png)

# %% [markdown]
# ![image.png](attachment:4b007a5b-8e2d-4b03-9a59-dbe90669ec7f.png)

# %% [markdown]
# ![image.png](attachment:81a7d445-452d-451c-805f-445c27911b82.png)

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
    def print_list(self):
        current = self
        while current:
            print(current.val, end=" -> ")
            current = current.next
        print("None")

# %%
l3 = ListNode(3)
l2 = ListNode(4, l3)
l1 = ListNode(2, l2)

# %%
l6 = ListNode(4 )
l5 = ListNode(6, l6)
l4 = ListNode(5, l5)

# %%
l1.print_list()
# Out:
# 2 -> 4 -> 3 -> None

# %%
l4.print_list()
# Out:
# 5 -> 6 -> 4 -> None

# %%
def two_sum(head1, head2):
    cur = dummy = ListNode(0)
    carry = 0 
    while head1 or head2 or carry:
        a =  head1.val if head1 else 0
        b =  head2.val if head2 else 0
        summ = a + b + carry
        carry = summ//10
        cur.next = ListNode(summ%10) 
        cur = cur.next
        if head1 :
            head1 = head1.next
        if head2 :
            head2 = head2.next
    return dummy.next

# %%
a = two_sum(l1, l4)

# %%
a.print_list()
# Out:
# 7 -> 0 -> 8 -> None

# %% [markdown]
# here what we have is done created a dummy variable and curr pointer pointing towards it form where i will start puuting nodes into it, the first step is to create a carry holder from the total sum when need , started a while loop , extract values from both if LL exists then just add those with carry and from summ we just extracted the  carry form sum like this `//` and then extract the last value from the sum as well and create a node which is the next of dummy_LL, and then just update the both LL to next (after checking that)

# %%
15645345//10
# Out:
# 1564534

# %%
1564534%10
# Out:
# 4
