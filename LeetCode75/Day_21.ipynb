# %% [markdown]
# ![image.png](attachment:bf979d95-c97c-47d1-9e1e-d0ce4cd1fa04.png)

# %% [markdown]
# ![image.png](attachment:b70b69f3-7254-4d9d-b48a-180762b3ec71.png)

# %% [markdown]
# ![image.png](attachment:e14be77f-fb13-49ac-a048-36a0041cc306.png)

# %% [markdown]
# ![image.png](attachment:3b0e5eaa-c7ab-401c-9601-1eb11b60a27d.png)

# %% [markdown]
# ![image.png](attachment:aba3a58d-1e38-4fb4-a22b-9b4197ac23a5.png)

# %% [markdown]
# ![image.png](attachment:a6ee87dd-3c7c-4eb4-9ca5-c567145c307f.png)

# %% [markdown]
# ![image.png](attachment:51a77ece-ef3a-4fbc-891d-284900e19297.png)

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
    def print_list(self):
        current = self
        while current:
            print(current.val, end=" -> ")
            current = current.next
        print("None")

# %%
l4 = ListNode(3)
l3 = ListNode(1, l4)
l2 = ListNode(2, l3)
l1 = ListNode(4, l2)

# %%
l1.print_list()
# Out:
# 4 -> 2 -> 1 -> 3 -> None

# %%
def sorted_List(head):
    if not head or not head.next:
        return head
    slow,fast = head, head.next
    while fast and fast.next:
        fast = fast.next.next
        slow = slow.next
    mid = slow.next
    slow.next = None
    l1 = sorted_List(head)
    l2 = sorted_List(mid)
    return merge(l1,l2)

# %%
def merge(l1 ,l2):
        dummy = ListNode()   
        hd = dummy        

        while l1 and l2:
            if l1.val < l2.val:
                hd.next = l1
                l1 = l1.next
            else :
                hd.next = l2
                l2 = l2.next
            hd = hd.next
        
        tail.next = l1 if l1 else l2

        return dummy.next

# %%
a =  sorted_List(l1)
a.print_list()
# Out:
# 4 -> None
