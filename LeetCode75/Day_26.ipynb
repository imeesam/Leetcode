# %% [markdown]
# ![image.png](attachment:8cb8e28d-4526-4df2-84c0-c9ffc692450a.png)

# %% [markdown]
# ![image.png](attachment:47b37a83-154d-46a2-8241-cb7a9654cd50.png)

# %% [markdown]
# ![image.png](attachment:62bcafa7-0a70-4eea-a92b-94c4c16dfa4f.png)
