# %% [markdown]
# ![image.png](attachment:d836348c-02e5-4793-bc73-b097d7ec47fb.png)

# %% [markdown]
# ![image.png](attachment:7e2584a4-5b03-4669-a4e1-c7fde53231c3.png)

# %% [markdown]
# ![image.png](attachment:1356d35c-fd87-4e0b-8249-69d10135c5cb.png)

# %% [markdown]
# ![image.png](attachment:d18ee6c1-c43b-471e-acf1-2bbf22f07529.png)

# %% [markdown]
# ![image.png](attachment:685d20b7-1f8c-4b87-83a1-0856a80ea464.png)

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# Create nodes
node15 = TreeNode(15)
node7 = TreeNode(7)
node20 = TreeNode(20, node15, node7)
node9 = TreeNode(9)
root = TreeNode(3, node9, node20)

# %%
from collections import deque
def min_depth(root):
    if not root:
        return 0

    queue = deque([(root,1)])
    while queue:
        node , level = queue.popleft()
        if not node.left and not node.right:
            return level
        if node.left:
            queue.append((node.left,level+1))
        if node.right:
            queue.append((node.right,level+1))
    return 0

# %%
min_depth(root)
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:d9dae65b-007f-44f4-9195-0593f7201b7c.png)

# %%
def max_depth(root):
    if not root:
        return 0

    queue = deque([(root, 1)])
    max_level = 0   # <-- tweak: track max depth

    while queue:
        node, level = queue.popleft()
        max_level = max(max_level, level)  # <-- update as we go
        if node.left:
            queue.append((node.left, level + 1))
        if node.right:
            queue.append((node.right, level + 1))

    return max_level

# %%
# here just remove that the condition of this 
# if not node.left and not node.right:
#     return level

# %%
max_depth(root)
# Out:
# 3
