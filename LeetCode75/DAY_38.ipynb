# %% [markdown]
# ![image.png](attachment:17a65b71-d5c1-4f69-8de8-13a177acaa6f.png)

# %% [markdown]
# ![image.png](attachment:d136f4a9-adc2-4fb9-a52b-4a3fb20478ed.png)

# %% [markdown]
# ![image.png](attachment:bf32fe2a-5157-4653-b5e7-2896b39e6e1c.png)
