# %% [markdown]
# ![image.png](attachment:9463038d-ad3f-4726-8a5c-32dcf02f7c79.png)

# %% [markdown]
# ![image.png](attachment:57760759-7bd0-41ab-99b7-a8890d857520.png)

# %% [markdown]
# ![image.png](attachment:a5825605-3b8b-4711-8032-cb828ac23576.png)

# %% [markdown]
# ![image.png](attachment:7b426c7d-d088-4e07-b3a6-5643822df9f4.png)

# %% [markdown]
# ![image.png](attachment:5f9feaf5-618d-4416-ae66-02eb76ec1b39.png)
# \
# \
# ![image.png](attachment:0ab40a70-655d-4901-84c0-0400d6750344.png)

# %% [markdown]
# ![image.png](attachment:97375655-d2ea-47cb-b4b6-3c5de233ddb2.png)
# \
# ![image.png](attachment:48139dbd-447a-43b6-9d35-aaf99ae5a6e7.png)
# \
# ![image.png](attachment:d5d68e04-a8d0-4da0-b1a0-1277f93235cd.png)

# %% [markdown]
# ![image.png](attachment:5fea6315-8183-4084-9cb7-556348d49738.png)

# %%
strsss = ["dog","racecar","car"]
strss = ["flower","flow","flight"]

# %%
def common_prefix(strs):
    if not strs:
        return ""
    prefix = strs[0]
    for i in strs[1:]:
        while not i.startswith(prefix):
            prefix = prefix[:-1]
            if not prefix:
                return ""
    return prefix

# %%
common_prefix(strss)
# Out:
# 'fl'

# %%
def lol(strs):
    if not strs:
        return ""
        
    prefix = strs[0]
    print(prefix)
    for i in strs[1:]:
        print(i)
        while not i.startswith(prefix):
            prefix = prefix[:-1]
            print(prefix)
            if not prefix:
                return ""
    return prefix

# %%
lol(strs)
# Out:
# flower
# flow
# flowe
# flow
# flight
# flo
# fl
# 'fl'

# %% [markdown]
# ![image.png](attachment:4848a81c-a91e-4c8c-ae91-b06c9d6765cd.png)

# %% [markdown]
# # --------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:0368fabb-e625-4822-9bf1-13e906528f3b.png)

# %% [markdown]
# ![image.png](attachment:9c49a7fd-5b76-411e-a661-efb8f292c6c0.png)

# %% [markdown]
# ![image.png](attachment:8cdccdde-0710-4674-9e89-4588cad2f656.png)

# %% [markdown]
# ![image.png](attachment:d2a8288d-4585-492a-ab13-7999bedaee62.png)

# %% [markdown]
# ![image.png](attachment:5872f6db-4c76-45f5-b416-4ca054368dd2.png)

# %% [markdown]
# ![image.png](attachment:351c9a4f-ac4e-48bc-8e1f-7e4119978dbd.png)

# %% [markdown]
# ![image.png](attachment:406c50b6-5ddd-4dfd-9207-68a9d6700420.png)

# %% [markdown]
# ![image.png](attachment:da442b25-2efe-429b-a96d-1037abe2f199.png)

# %% [markdown]
# ![image.png](attachment:c452955c-bb03-4b6e-8a8d-0828a0d01e5b.png)

# %% [markdown]
# ![image.png](attachment:193f5e6b-f8d0-4e5d-97b5-14318cdcae7b.png)

# %% [markdown]
# ![image.png](attachment:3f193100-884c-4c81-b841-5ba7e2293619.png)

# %%
def comb_sum(candidates, target):
    res = []
    def backtrack(start , path , total):
        if total == target:
            res.append(path[:])
            return

        if total > target:
            return 

        for i in range(start, len(candidates)):
            path.append(candidates[i])
            backtrack(i,path,total + candidates[i])
            path.pop()

    backtrack(0,[],0)
    return res

# %%
    def comb_sum(candidates, target):
        res = []

        def backtrack(start, path, total):
            # Base cases
            if total == target:
                res.append(path[:])
                return
            if total > target:
                return
            
            # Explore options
            for i in range(start, len(candidates)):
                path.append(candidates[i])
                backtrack(i, path, total + candidates[i])  # reuse allowed
                path.pop()  # backtrack

        backtrack(0, [], 0)
        return res

# %% [markdown]
# # --------------------------------------------------------------------------------------------

# %% [markdown]
# ![image.png](attachment:aef71779-a2b7-464c-b0a3-08f1eee79ccb.png)

# %% [markdown]
# ![image.png](attachment:68f483f2-4579-41fa-a1a2-f1e9992e1b4e.png)

# %% [markdown]
# ![image.png](attachment:ed28f399-2fa2-497e-9efb-9b37d18ec06e.png)

# %% [markdown]
# ![image.png](attachment:42eed1b3-fe85-485d-a92b-ceaa6c4e063b.png)

# %% [markdown]
# Convert the given number into the Roman numeral representation while respecting these rules.

# %% [markdown]
# ![image.png](attachment:aa679196-6732-4ba9-9420-f944e4215ab9.png)

# %% [markdown]
# ![image.png](attachment:8eedc3fd-926c-424b-a551-22df7c0f7f74.png)

# %% [markdown]
# ![image.png](attachment:68677d07-39de-41aa-bf8b-fa0bb4bd556d.png)

# %%
def rti(nums):
    values =  [1000, 900, 500, 400, 100, 90, 50, 40, 10, 9, 5, 4, 1]
    symbols = ["M", "CM", "D", "CD", "C", "XC", "L", "XL", "X", "IX", "V", "IV", "I"]
    roman = ""
    for i in range(len(values)):
        while nums>=values[i]:
            nums-=values[i]
            roman+=symbols[i]
    return roman

# %%
rti_d(9)
# Out:
# 'IX'

# %%
def rti_d(num):
    roman_map = {
        1000: "M",
        900:  "CM",
        500:  "D",
        400:  "CD",
        100:  "C",
        90:   "XC",
        50:   "L",
        40:   "XL",
        10:   "X",
        9:    "IX",
        5:    "V",
        4:    "IV",
        1:    "I"
    }
    res = []
    for i in sorted(roman_map.keys(), reverse = True):
        while num>=i:
            res.append(roman_map[i])
            num-=i
    return ''.join(res)

# %% [markdown]
# ![image.png](attachment:438aefaf-ae00-44b2-a31d-1d5efae097b4.png)

# %% [markdown]
# ![image.png](attachment:e6869988-d7ba-43a6-9c00-1d7db7a86326.png)

# %% [markdown]
# ![image.png](attachment:f266f54b-d128-4327-af5d-28c936f2d9e3.png)
