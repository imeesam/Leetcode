# %% [markdown]
# ![image.png](attachment:09194106-ad06-42cf-8ae3-63f0574d2b4a.png)

# %% [markdown]
# ![image.png](attachment:cc2124b6-b0d2-4672-8c16-108b52348e89.png)

# %% [markdown]
# ![image.png](attachment:0e17276e-5d09-431b-bc9c-0af699f2b0b5.png)

# %% [markdown]
# ![image.png](attachment:1e21a78b-308a-4e3a-a84a-9bcfb06e6ff7.png)

# %% [markdown]
# ![image.png](attachment:b1fa0786-f2b7-4976-92c1-616e25e216da.png)
# \
# \
# First part

# %% [markdown]
# ![image.png](attachment:ec9f4aa7-6286-430c-bcfb-23cc7010a122.png)
# \
# Second part

# %% [markdown]
# ![image.png](attachment:b31b2f89-b560-4b9c-998b-48c1cb2d4a19.png)
# \
# \
# third part

# %% [markdown]
# ![image.png](attachment:720fe36a-9397-4602-bd7e-f218643ae472.png)

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
    def print_list(self):
        current = self
        while current:
            print(current.val, end=" -> ")
            current = current.next
        print("None")

# %%
l5 = ListNode(5)
l4 = ListNode(4, l5)
l3 = ListNode(3, l4)
l2 = ListNode(2, l3)
l1 = ListNode(1, l2)

# %%
l1.print_list()
# Out:
# 1 -> 2 -> 3 -> 4 -> 5 -> None

# %%
def reverse_list(head, left, right):
    dummy_head = ListNode(-1,head)
    left_prev,curr_node = dummy_head,head
    for i in range(left-1):
        left_prev,curr_node = curr_node , curr_node.next

    prev = None
    for i in range(right-left+1):
        next_pointer = curr_node.next
        curr_node.next = prev
        prev , curr_node =  curr_node , next_pointer

    left_prev.next.next = curr_node
    left_prev.next = prev
    return dummy_head.next

# %%
head = l1
left = 2
right = 4
reversed_list = reverse_list(head, left, right)

# %%
dummy_head.print_list()
# Out:
# -1 -> 1 -> None

# %%
reversed_list.print_list()
# Out:
# 1 -> 4 -> 3 -> 2 -> 5 -> None

# %% [markdown]
# ![image.png](attachment:8f9ea481-b420-44ce-b30d-371c9aa9dd01.png)

# %% [markdown]
# ![image.png](attachment:b2b87cea-b5ad-4cba-a555-87501341eb7c.png)

# %% [markdown]
# ![image.png](attachment:9db76ad3-6e15-4363-9688-9f7dc510bda1.png)
