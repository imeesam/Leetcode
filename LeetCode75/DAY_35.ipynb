# %% [markdown]
# # Diameter of binary tree

# %% [markdown]
# Find the longest possible path between any two nodes in our bianry tree

# %% [markdown]
# ![image.png](attachment:33b3c702-e788-4ad7-b594-333332fe7947.png)

# %% [markdown]
# lonngest path is between 4 and 3

# %% [markdown]
# recursive would be more easier to understand if compared with iterative

# %% [markdown]
# both soultion is using BFS to solve this paticular problem
# \
# \
# `breadth first search`

# %% [markdown]
# at each node we are calculating maximum diameter by considering sum of left and right subtree

# %% [markdown]
# in iterative solution the diameter is returned backed to the core satck

# %% [markdown]
# onmce hazve depths at each node we calculate the maximum updating our global tracker

# %% [markdown]
# to make sure we have the max

# %% [markdown]
# ![image.png](attachment:3d0577b5-96d0-4ddc-a76d-a1208ce70a65.png)

# %% [markdown]
# ![image.png](attachment:b62704ac-2e5e-4dfa-9196-6fa822ea47b7.png)

# %% [markdown]
# ![image.png](attachment:e948d130-2cb9-47ca-9da3-2464fe7cafd8.png)

# %%
def diameter(root):
    diameter = 0 
    def depth(root):
        if not root:
            return 0 
        left_depth = depth(root.left)
        right_depth = depth(root.right)

        diameter = max(diameter , left_depth+right_depth)
        return 1+max(left_depth,right_depth)

    depth(root)
    return diameter

# %% [markdown]
# https://leetcode.com/submissions/detail/1822259885/
