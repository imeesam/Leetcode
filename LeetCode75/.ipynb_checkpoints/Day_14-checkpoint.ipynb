# %% [markdown]
# ![image.png](attachment:4146ae26-f1d4-4dc2-a60e-830f1b908820.png)

# %% [markdown]
# ![image.png](attachment:818e6569-121e-4653-b936-10e5959efd34.png)

# %% [markdown]
# ![image.png](attachment:dabb9fd5-7037-45d5-ac63-892c230aecaa.png)

# %% [markdown]
# ![image.png](attachment:2b6122c7-4187-4e1d-9689-d7f14e0d67f0.png)

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
    def print_list(self):
        current = self
        while current:
            print(current.val, end=" -> ")
            current = current.next
        print("None")

# %%
l5 = ListNode(5)
l4 = ListNode(4, l5)
l3 = ListNode(6, l4)
l2 = ListNode(2, l3)
l1 = ListNode(1, l2)

# %%
def del_ll(head,val):
    dummy_head = ListNode(-1)
    dummy_head.next = head
    curr_pointer = dummy_head
    while curr_pointer.next:
        if curr_pointer.next.val == val:
            curr_pointer.next =curr_pointer.next.next
        else:
            curr_pointer = curr_pointer.next
    dummy_head.print_list()
    return dummy_head.next

# %%
del_ll(l1,6)
# Out:
# -1 -> 1 -> 2 -> 5 -> None
