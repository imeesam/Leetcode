# %% [markdown]
# ![image.png](attachment:82647b85-3779-4e8a-8a57-94ee5a61a830.png)

# %% [markdown]
# ![image.png](attachment:1303a4bb-24f0-48e5-896d-38a32486b018.png)

# %% [markdown]
# ![image.png](attachment:b2e0b7ea-5181-4c26-91ba-b40d56de6fce.png)

# %% [markdown]
# ![image.png](attachment:0e8aec87-4946-4b97-b1ef-de0433bb9acd.png)

# %% [markdown]
# ![image.png](attachment:d4bda5c3-c9a4-45f4-beea-411c86614c73.png)

# %% [markdown]
# ![image.png](attachment:6f773655-327f-44c2-9878-cc80807a2d38.png)

# %% [markdown]
# ![image.png](attachment:1a2c5bc8-c8a7-41d4-bbf2-6ba8d91010ff.png)

# %%
def counting_bits(n):
    dp = [0]* (n+1)
    offset = 1
    for i in range(1,n+1):
        if offset*2 == i:
            offset = i
        dp[i] = 1 + dp[i-offset]
    return dp

# %%
counting_bits(2)
# Out:
# [0, 0, 1]

# %% [markdown]
# ![image.png](attachment:1effb34e-fc40-414d-86ec-3cb7ca22e2bf.png)
