# %% [markdown]
# ![image.png](attachment:b2b8db48-83cf-4ab7-9998-82e28c56cc26.png)

# %% [markdown]
# ![image.png](attachment:28932350-640b-44b9-85ff-4ea8993ff61f.png)

# %% [markdown]
# ![image.png](attachment:497b53cf-81c7-432d-8e4d-44f6bb2df730.png)

# %% [markdown]
# Create a dummy ll assign, and and a iterator on that dummy then compare the values of the both head if small update from l1 if large update from l2 and then if ll are not equal one for appending that to after while

# %% [markdown]
# ![image.png](attachment:a0ce69ef-95da-4090-8d4c-a1dba5cb7036.png)

# %% [markdown]
# ![image.png](attachment:cc96a121-0d70-4b07-bcb6-af19fb6e1f9e.png)

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
    def print_list(self):
        current = self
        while current:
            print(current.val, end=" -> ")
            current = current.next
        print("None")

# %%
l3 = ListNode(4)
l2 = ListNode(2, l3)
l1 = ListNode(1, l2)

# %%
l8 = ListNode(7)
l7 = ListNode(5 , l8)
l6 = ListNode(4 , l7)
l5 = ListNode(3, l6)
l4 = ListNode(1, l5)

# %%
l1.print_list()
# Out:
# 1 -> 2 -> 4 -> None

# %%
l4.print_list()
# Out:
# 1 -> 3 -> 4 -> 5 -> 7 -> None

# %%
def two_sorted_ll(list1, list2):
    cur = dummyll = ListNode()
    while list1 and list2:
        if list1.val < list2.val:
            cur.next = list1
            list1,cur = list1.next,list1
        else:
            cur.next = list2
            list2,cur = list2.next,list2
    if list1 or list2:
        cur.next = list1 if list1 else list2

    return dummyll.next

# %%
a = two_sorted_ll(l1,l4)
a.print_list()
# Out:
# 1 -> 1 -> 2 -> 3 -> 4 -> 4 -> 5 -> 7 -> None
