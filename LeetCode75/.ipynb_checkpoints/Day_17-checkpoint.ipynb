# %% [markdown]
# ![image.png](attachment:b5fb7829-9db9-469d-8324-a21101286b3e.png)

# %% [markdown]
# ![image.png](attachment:4c6b7f7b-699f-41a9-b5f5-70d891cf1b72.png)

# %% [markdown]
# ![image.png](attachment:fdba10d8-1241-4bc2-b3ce-a58ca630475d.png)

# %% [markdown]
# using concepts from different question here what we have done

# %% [markdown]
# ![image.png](attachment:2f4d3440-a85e-4ce3-8b65-9df951dee0ea.png)

# %% [markdown]
# ![image.png](attachment:86d9ab7a-6ceb-4681-9ef1-a28d925eb9db.png)
# \
# ![image.png](attachment:6e243210-392e-42cd-8a42-794497b9c619.png)
# \
# ![image.png](attachment:c8315934-d868-4c91-84ed-780801750f6a.png)
# \
# ![image.png](attachment:ed361253-a5cb-4836-88c9-041be163add4.png)
# \
# ![image.png](attachment:ae53e8b8-b668-4412-b657-c64b92caca05.png)
# \
# ![image.png](attachment:370cfd20-9a9d-4b55-9065-aabb4ecbe489.png)
# \
# ![image.png](attachment:6bf4d34b-bbf9-4c1a-a1c1-678802d78b7f.png)
# \
# ![image.png](attachment:e448dac4-95e6-49b1-b87e-a5deac63190a.png)
# \
# ![image.png](attachment:5e730da4-65cf-4172-bfed-b22555da460b.png)
# \
# ![image.png](attachment:6ef93d9b-815d-45a0-8d7a-8a2ebd0d3232.png)
# \
# ![image.png](attachment:a29d3262-983d-40a4-938b-c92e02f7e216.png)

# %% [markdown]
# frist all what we have done is that we have find the middle of the LL with the help of the two pointers by moving twice one as compared to anothers one then later what we have done is that we ahve used the concept of the reversing the array of the half LL not the whole, then we just created the none which points to previous , and then starting revering the LL there initailazed another pointer there , after reversing the arrya create wo more pointers there and check if there value ae similat if not then breakm

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
    def print_list(self):
        current = self
        while current:
            print(current.val, end=" -> ")
            current = current.next
        print("None")

# %%
l4 = ListNode(1)
l3 = ListNode(2, l4)
l2 = ListNode(2, l3)
l1 = ListNode(1, l2)

# %%
l1.print_list()
# Out:
# 1 -> 2 -> 2 -> 1 -> None

# %%
def palindrome(head):
    fast = slow = head
    while fast and fast.next:
        fast = fast.next.next
        slow = slow.next

    prev = None
    while slow:
        next_pointer = slow.next
        slow.next = prev

        prev = slow
        slow = next_pointer

    left = head 
    right = prev
    while right:
        if  left.val != right.val:
            return False

        left = left.next
        right = right.next

    return True

# %%
 palindrome(l1)
# Out:
# True

# %%
l1.print_list()
# Out:
# 1 -> 2 -> 2 -> None
