# %% [markdown]
# ![image.png](attachment:5891460a-523c-4667-9886-c46ecdaba1ae.png)

# %% [markdown]
# ![image.png](attachment:ea34c8d4-b734-49f2-b628-6e70605b796a.png)

# %% [markdown]
# ![image.png](attachment:a73233ad-0f1a-46bd-b51d-a3088589438e.png)

# %% [markdown]
# ![image.png](attachment:e342b45a-ed9e-472c-a3d2-fb1bc90127ef.png)

# %% [markdown]
# uses `5 once` and `1 twice` which `is equal to 7`

# %% [markdown]
# if we use this `depth first search` then we can led that to this whole tree,
# \
# \
# ![image.png](attachment:a277edb1-e832-417b-8a9a-67a79296a871.png)

# %% [markdown]
# ![image.png](attachment:3200260b-f8a9-4e52-b1d5-1b8fb875ee79.png)

# %% [markdown]
# ![image.png](attachment:2ab9b8fa-ea59-4483-aca4-2020b1847682.png)

# %% [markdown]
# new min
# \
# \
# ![image.png](attachment:c767eec2-2b1c-4006-9fe9-2f53dd998bd6.png)

# %% [markdown]
# ![image.png](attachment:04654ec4-d6e0-4ba7-86f5-1776081ac3b8.png)
# \
# ![image.png](attachment:94ff3d8f-b467-4a2e-909f-b687ff35984a.png)

# %% [markdown]
# ![image.png](attachment:cf0b81c3-33c2-4158-9d88-d4176053e944.png)

# %% [markdown]
# ![image.png](attachment:5cc54228-171b-4145-b3f8-d8c187020dd4.png)

# %%
def coin_change(coins,amount):
    dp = [amount+1]*(amount+1)
    dp[0] = 0
    for i in range(1,amount+1):
        for c in coins:
            if ((i-c)>=0):
                dp[i] = min(dp[i], 1+dp[i-c])
    return dp[amount] if (dp[amount] != amount+1) else -1

# %%
coin_change([1,2,5],11)
# Out:
# 3
